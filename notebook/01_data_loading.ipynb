# %%
print("Setup Successful")
# Out:
# Setup Successful

# %%
import pandas as pd

crop_df = pd.read_csv('../data/archive/Custom_Crops_yield_Historical_Dataset.csv')

crop_df.head()
# Out:
#    Dist Code  Year  State Code    State Name Dist Name      Crop   Area_ha  \
# 0          1  1966          14  Chhattisgarh      Durg      rice  548000.0
# 1          1  1966          14  Chhattisgarh      Durg     maize    3000.0
# 2          1  1966          14  Chhattisgarh      Durg  chickpea   54000.0
# 3          1  1967          14  Chhattisgarh      Durg      rice  547000.0
# 4          1  1967          14  Chhattisgarh      Durg     maize    3000.0
#
#    Yield_kg_per_ha  N_req_kg_per_ha  P_req_kg_per_ha  K_req_kg_per_ha  \
# 0           337.59          8.43975          4.05108          7.42698
# 1           666.67         18.00009          8.00004         11.33339
# 2           500.00          9.00000          5.00000          9.00000
# 3           747.71         18.69275          8.97252         16.44962
# 4          1000.00         27.00000         12.00000         17.00000
#
#     Total_N_kg  Total_P_kg  Total_K_kg  Temperature_C  Humidity_%   pH  \
# ...

# %%
ndvi_df = pd.read_excel('../data/NDTV/climate_data/ndvi_1998_2013.xlsx')

ndvi_df.head()
# Out:
#         date  NDVI_mean  NDVI_std  NDVI_min  NDVI_max  NDVI_count dataset  \
# 0 2000-02-29   0.307407       NaN  0.307407  0.307407           1   MODIS
# 1 2000-03-31   0.263443  0.012329  0.254726  0.272161           2   MODIS
# 2 2000-04-30   0.232063  0.006700  0.227325  0.236801           2   MODIS
# 3 2000-05-31   0.239022  0.007318  0.233847  0.244197           2   MODIS
# 4 2000-06-30   0.295799  0.034617  0.271321  0.320277           2   MODIS
#
#        region
# 0  Marathwada
# 1  Marathwada
# 2  Marathwada
# 3  Marathwada
# 4  Marathwada

# %%
rainfall_df = pd.read_excel('../data/NDTV/climate_data/chirps_rainfall_timeseries.xlsx')

rainfall_df.head()
# Out:
#    system:index       date  precipitation      region  system:band_names  \
# 0  1_1_20200101 2020-01-01       0.019835  Marathwada                NaN
# 1  1_1_20200102 2020-01-02       0.191575  Marathwada                NaN
# 2  1_1_20200103 2020-01-03       0.000000  Marathwada                NaN
# 3  1_1_20200104 2020-01-04       0.000000  Marathwada                NaN
# 4  1_1_20200105 2020-01-05       0.000000  Marathwada                NaN
#
#    system:bands                                    .geo
# 0           NaN  {"type":"MultiPoint","coordinates":[]}
# 1           NaN  {"type":"MultiPoint","coordinates":[]}
# 2           NaN  {"type":"MultiPoint","coordinates":[]}
# 3           NaN  {"type":"MultiPoint","coordinates":[]}
# 4           NaN  {"type":"MultiPoint","coordinates":[]}

# %%
crop_df.columns
# Out:
# Index(['Dist Code', 'Year', 'State Code', 'State Name', 'Dist Name', 'Crop',
#        'Area_ha', 'Yield_kg_per_ha', 'N_req_kg_per_ha', 'P_req_kg_per_ha',
#        'K_req_kg_per_ha', 'Total_N_kg', 'Total_P_kg', 'Total_K_kg',
#        'Temperature_C', 'Humidity_%', 'pH', 'Rainfall_mm', 'Wind_Speed_m_s',
#        'Solar_Radiation_MJ_m2_day'],
#       dtype='object')

# %%
crop_df['State Name'].unique()
# Out:
# array(['Chhattisgarh', 'Madhya Pradesh', 'Andhra Pradesh', 'Telangana',
#        'Karnataka', 'Tamil Nadu', 'Maharashtra', 'Gujarat', 'Rajasthan',
#        'Punjab', 'Haryana', 'Uttar Pradesh', 'Uttarakhand', 'Assam',
#        'Himachal Pradesh', 'Kerala', 'Orissa', 'West Bengal', 'Bihar',
#        'Jharkhand'], dtype=object)

# %%
crop_df[crop_df['State Name'] == 'YourStateHere']['Crop'].unique()
# Out:
# array([], dtype=object)

# %%
crop_df['State Name'].unique()
# Out:
# array(['Chhattisgarh', 'Madhya Pradesh', 'Andhra Pradesh', 'Telangana',
#        'Karnataka', 'Tamil Nadu', 'Maharashtra', 'Gujarat', 'Rajasthan',
#        'Punjab', 'Haryana', 'Uttar Pradesh', 'Uttarakhand', 'Assam',
#        'Himachal Pradesh', 'Kerala', 'Orissa', 'West Bengal', 'Bihar',
#        'Jharkhand'], dtype=object)

# %%
ka_df = crop_df[crop_df['State Name'] == 'Karnataka']

ka_df.head()
# Out:
#        Dist Code  Year  State Code State Name  Dist Name      Crop  Area_ha  \
# 11090         64  1966           5  Karnataka  Bangalore      rice  45000.0
# 11091         64  1966           5  Karnataka  Bangalore  chickpea   4000.0
# 11092         64  1967           5  Karnataka  Bangalore      rice  36000.0
# 11093         64  1967           5  Karnataka  Bangalore     maize   3000.0
# 11094         64  1967           5  Karnataka  Bangalore  chickpea   5000.0
#
#        Yield_kg_per_ha  N_req_kg_per_ha  P_req_kg_per_ha  K_req_kg_per_ha  \
# 11090          1444.44         36.11100         17.33328         31.77768
# 11091          1000.00         18.00000         10.00000         18.00000
# 11092           583.33         14.58325          6.99996         12.83326
# 11093          1333.33         35.99991         15.99996         22.66661
# 11094           400.00          7.20000          4.00000          7.20000
#
# ...

# %%
ka_df['Crop'].unique()
# Out:
# array(['rice', 'chickpea', 'maize', 'cotton'], dtype=object)

# %%
crop_df[crop_df['State Name'] == 'YourStateHere']['Crop'].unique()
# Out:
# array([], dtype=object)

# %%
ka_df = crop_df[crop_df['State Name'] == 'Karnataka']

ka_df['Crop'].unique()
# Out:
# array(['rice', 'chickpea', 'maize', 'cotton'], dtype=object)

# %%
crop_df['State Name'] == 'YourStateHere'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 50760    False
# 50761    False
# 50762    False
# 50763    False
# 50764    False
# Name: State Name, Length: 50765, dtype: bool

# %%
ka_rice_df = ka_df[ka_df['Crop'] == 'rice']

ka_rice_df.head()
# Out:
#        Dist Code  Year  State Code State Name  Dist Name  Crop  Area_ha  \
# 11090         64  1966           5  Karnataka  Bangalore  rice  45000.0
# 11092         64  1967           5  Karnataka  Bangalore  rice  36000.0
# 11095         64  1968           5  Karnataka  Bangalore  rice  35300.0
# 11098         64  1969           5  Karnataka  Bangalore  rice  37300.0
# 11100         64  1970           5  Karnataka  Bangalore  rice  43500.0
#
#        Yield_kg_per_ha  N_req_kg_per_ha  P_req_kg_per_ha  K_req_kg_per_ha  \
# 11090          1444.44         36.11100         17.33328         31.77768
# 11092           583.33         14.58325          6.99996         12.83326
# 11095          1218.13         30.45325         14.61756         26.79886
# 11098          1109.92         27.74800         13.31904         24.41824
# 11100          1464.37         36.60925         17.57244         32.21614
#
#         Total_N_kg  Total_P_kg   Total_K_kg  Temperature_C  Humidity_%   pH  \
# ...

# %%
ka_rice_df['Year'].min(), ka_rice_df['Year'].max()
# Out:
# (1966, 2017)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(ka_rice_df['Year'], ka_rice_df['Yield_kg_per_ha'], marker='o')
plt.xlabel('Year')
plt.ylabel('Yield (kg per ha)')
plt.title('Rice Yield Trend in Karnataka')
plt.grid(True)
plt.show()

# %%
ka_rice_df = ka_rice_df[ka_rice_df['Year'] >= 2000]

ka_rice_df['Year'].min(), ka_rice_df['Year'].max()
# Out:
# (2000, 2017)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(ka_rice_df['Year'], ka_rice_df['Yield_kg_per_ha'], marker='o')
plt.xlabel('Year')
plt.ylabel('Yield (kg per ha)')
plt.title('Rice Yield Trend in Karnataka (2000-2017)')
plt.grid(True)
plt.show()
