# %%
import pandas as pd
import matplotlib.pyplot as plt

ka_rice_df = pd.read_csv('../data/karnataka_rice_2000_2017.csv')
ka_rice_df.head()
# Out:
#    Dist Code  Year  State Code State Name  Dist Name  Crop  Area_ha  \
# 0         64  2000           5  Karnataka  Bangalore  rice  29400.0
# 1         64  2001           5  Karnataka  Bangalore  rice  19660.0
# 2         64  2002           5  Karnataka  Bangalore  rice   9050.0
# 3         64  2003           5  Karnataka  Bangalore  rice   9220.0
# 4         64  2004           5  Karnataka  Bangalore  rice  12870.0
#
#    Yield_kg_per_ha  N_req_kg_per_ha  P_req_kg_per_ha  K_req_kg_per_ha  \
# 0          2585.03         64.62575         31.02036         56.87066
# 1          2396.74         59.91850         28.76088         52.72828
# 2          2245.30         56.13250         26.94360         49.39660
# 3          2529.28         63.23200         30.35136         55.64416
# 4          3042.74         76.06850         36.51288         66.94028
#
#     Total_N_kg   Total_P_kg    Total_K_kg  Temperature_C  Humidity_%   pH  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

ka_rice_df = pd.read_csv('../data/karnataka_rice_2000_2017.csv')

ka_rice_df.head()
# Out:
#    Dist Code  Year  State Code State Name  Dist Name  Crop  Area_ha  \
# 0         64  2000           5  Karnataka  Bangalore  rice  29400.0
# 1         64  2001           5  Karnataka  Bangalore  rice  19660.0
# 2         64  2002           5  Karnataka  Bangalore  rice   9050.0
# 3         64  2003           5  Karnataka  Bangalore  rice   9220.0
# 4         64  2004           5  Karnataka  Bangalore  rice  12870.0
#
#    Yield_kg_per_ha  N_req_kg_per_ha  P_req_kg_per_ha  K_req_kg_per_ha  \
# 0          2585.03         64.62575         31.02036         56.87066
# 1          2396.74         59.91850         28.76088         52.72828
# 2          2245.30         56.13250         26.94360         49.39660
# 3          2529.28         63.23200         30.35136         55.64416
# 4          3042.74         76.06850         36.51288         66.94028
#
#     Total_N_kg   Total_P_kg    Total_K_kg  Temperature_C  Humidity_%   pH  \
# ...

# %%
plt.figure(figsize=(10,5))
plt.plot(ka_rice_df['Year'], ka_rice_df['Yield_kg_per_ha'], marker='o')
plt.xlabel('Year')
plt.ylabel('Yield (kg per ha)')
plt.title('Rice Yield Trend in Karnataka (2000–2017)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Extended Yield Analysis (Prediction till 2025)

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

df = pd.read_csv('../data/tamilnadu_rice_2000_2017.csv', usecols=['Year', 'Yield_kg_per_ha'])

df = df.dropna()

X = df['Year'].values.reshape(-1,1)
y = df['Yield_kg_per_ha'].values

model = LinearRegression().fit(X, y)

future_years = np.array([2024, 2025]).reshape(-1,1)
pred = model.predict(future_years)

print("Yield Predictions:", dict(zip([2024, 2025], pred)))
# Out:
# Yield Predictions: {2024: 4509.349867274403, 2025: 4571.840641268209}

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10,5))
plt.plot(df['Year'], df['Yield_kg_per_ha'], marker='o', label='Actual Yield')

future_years = [2024, 2025]
plt.scatter(future_years, pred, color='red', s=100, label='Predicted Yield')

last_year = df['Year'].iloc[-1]
last_value = df['Yield_kg_per_ha'].iloc[-1]

plt.plot([last_year, 2024, 2025],
         [last_value, pred[0], pred[1]],
         linestyle='dashed')

plt.xlabel('Year')
plt.ylabel('Yield (kg per ha)')
plt.title('Rice Yield Trend with Prediction (2000–2025)')
plt.legend()
plt.grid(True)

plt.show()
